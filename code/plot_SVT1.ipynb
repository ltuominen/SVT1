# %%
import matplotlib.pyplot as plt
from nilearn import plotting
import os

# %%
base_path = os.path.dirname(os.getcwd())
#SUBJECTS_DIR = f'{base_path}/SUBJECTS_DIR'
#MNI152 = '/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz'

svt1 = f'{base_path}/test_subject/mrtm2_sm6/bp.nii.gz'

fig, ax = plt.subplots(figsize=(10, 5))

plotting.plot_stat_map(
    svt1,
    vmin=1,
    vmax=6,
    draw_cross=False,
    black_bg=False,
    axes=ax
);
fig.suptitle(r'$[^{18}F]\mathrm{SynVesT1}$', fontsize=16);
# Out:
# Text(0.5, 0.98, '$[^{18}F]\\mathrm{SynVesT1}$')
